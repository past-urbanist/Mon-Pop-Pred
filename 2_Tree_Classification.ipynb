# %%
from google.colab import drive
drive.mount('/content/gdrive/')
path = '/content/gdrive/My Drive/Colab Notebooks/Thesis'
# Out:
# Mounted at /content/gdrive/

# %%
import re, os, random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error, precision_score, recall_score
import joblib

# %%
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()
from fastbook import *

from fastai.tabular import *
from fastai.tabular.all import *
from fastai.tabular.data import *
from fastai.tabular.learner import *
# Out:
#      |████████████████████████████████| 727kB 5.8MB/s
#      |████████████████████████████████| 1.2MB 53.2MB/s
#      |████████████████████████████████| 51kB 7.5MB/s
#      |████████████████████████████████| 194kB 55.8MB/s
#      |████████████████████████████████| 61kB 9.2MB/s
#      |████████████████████████████████| 51kB 7.8MB/s

# %%
data_ori = pd.read_csv(path+'/data1_sf.csv')
alist = data_ori.columns.to_list()
alist
# Out:
# ['country',
#  'fua_name',
#  'road_len',
#  'area',
#  'population',
#  'city_pop',
#  'cen_dist',
#  'night',
#  'land_cover',
#  'X',
#  'Y',
#  'city_id',
#  'population_cat']

# %%
alist = ['population_cat', 'night', 'road_len', 'city_pop', 'cen_dist', 'X', 'Y', 'land_cover','city_id']
data = data_ori[alist]

# %%
data.describe()
# Out:
#                night       road_len      city_pop       cen_dist  \
# count  260534.000000  260534.000000  2.605340e+05  260534.000000
# mean        4.625352       2.618643  4.394432e+06      48.840822
# std        12.620485       3.395864  3.148661e+06      26.506507
# min         0.000000       0.000000  1.207469e+06       0.088187
# 25%         0.347500       0.079500  2.120416e+06      29.361106
# 50%         0.712500       1.553339  2.939714e+06      44.830977
# 75%         2.750000       3.376450  4.814757e+06      63.796209
# max      1361.780000      40.156530  1.166596e+07     166.826791
#
#                    X              Y     land_cover        city_id
# count  260534.000000  260534.000000  260534.000000  260534.000000
# mean        9.948661      49.823713       6.632543      11.373537
# std         8.835994       5.054657       2.135577       5.586927
# min        -9.505698      38.409757       1.000000       1.000000
# 25%         2.452635      47.718090       7.000000       7.000000
# 50%        12.369302      50.759757       7.000000      12.000000
# 75%        16.669302      52.701424       8.000000      17.000000
# max        26.460969      60.259757      11.000000      22.000000

# %%
data.head()
# Out:
#    population_cat  night  road_len  city_pop   cen_dist          X          Y  \
# 0            True  0.110  0.358197   1704350  53.481355  -6.697365  53.001424
# 1           False  0.275  0.000000   3021243  36.127658   9.835969  53.868090
# 2            True  0.335  0.299463   4788590  70.356310  13.010969  51.984757
# 3            True  0.455  1.719590   2650374  53.448373  16.310969  47.701424
# 4            True  0.810  0.000000   1704350  17.568716  -6.472365  53.234757
#
#    land_cover  city_id
# 0           7       14
# 1           8        5
# 2           8        8
# 3           8        7
# 4           7       14

# %%
cat_names = alist[-2:]
cont_names = alist[1:-2]
y_names = alist[0]
procs = [Categorify,]

# %%
percent, length = 0.8, len(data.axes[0])
stop = int(percent * length)
splits = [list(range(stop)), list(range(stop,length))]

# %%
to = TabularPandas(data, procs=procs, cat_names=cat_names, cont_names=cont_names, y_names=y_names, splits=splits)

# %%
len(to.xs),len(to.train),len(to.valid)
# Out:
# (260534, 208427, 52107)

# %%
xs, y = to.xs,to.y
train_xs,train_y = to.train.xs,to.train.y
valid_xs,valid_y = to.valid.xs,to.valid.y

# %%
# param_grid = [{'n_estimators':[20], 'max_samples':[100000], 
#                'max_features': [0.5], 'min_samples_leaf':[3, 4, 5], 
#                'max_depth': [30, 35, 40]}]
# rf_test = RandomForestClassifier()

# %%
# rf_grid_search = GridSearchCV(rf_test, param_grid, cv=6, scoring='f1')
# rf_grid_search.fit(train_xs,train_y)

# %%
# rf_grid_search.best_params_

# %%
n_estimators = 500
max_samples = 100000
max_features = 0.5
min_samples_leaf = 4
max_depth = 25

# %%
rf = RandomForestClassifier(n_jobs=-1, n_estimators=n_estimators,
    max_samples=max_samples, max_features=max_features, max_depth=max_depth,
    min_samples_leaf=min_samples_leaf, oob_score=True)

# %%
import time
start = time.time()
m = rf.fit(train_xs, train_y);
end = time.time()
print('Time:', end-start)
# Out:
# Time: 129.8042769432068

# %%
precision_score(train_y, rf.predict(train_xs)), precision_score(valid_y, rf.predict(valid_xs))
# Out:
# (0.9351983070343233, 0.9056259040272033)

# %%
recall_score(train_y, rf.predict(train_xs)), recall_score(valid_y, rf.predict(valid_xs))
# Out:
# (0.9599352911247081, 0.9344365312107248)

# %%
train_preds = np.stack([t.predict(train_xs) for t in rf.estimators_])
valid_preds = np.stack([t.predict(valid_xs) for t in rf.estimators_])
train_preds.shape, valid_preds.shape
# Out:
# ((500, 208427), (500, 52107))

# %%
for name, score in zip(alist[1:], rf.feature_importances_):
    print('%s: %f' %(name, 100 *score)+"%")
# Out:
# night: 13.163930%
# road_len: 3.315768%
# city_pop: 17.632648%
# cen_dist: 32.965052%
# X: 3.493891%
# Y: 8.566055%
# land_cover: 10.684034%
# city_id: 10.178624%

# %%
# Save the model
joblib_file = path + '/classifier.pkl'
joblib.dump(m, joblib_file)
print('Model Saved!')
# Out:
# Model Saved!
